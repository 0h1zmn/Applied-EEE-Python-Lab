# %%
print("Hello, World!")
print("Welcome to Python programming.")
print("This is a simple script to demonstrate basic Python syntax.")
print("You can run this script using Python 3.")
print("Feel free to modify and experiment with the code!")
print("Goodbye, World!")
# Out:
# Hello, World!
# Welcome to Python programming.
# This is a simple script to demonstrate basic Python syntax.
# You can run this script using Python 3.
# Feel free to modify and experiment with the code!
# Goodbye, World!

# %%
voltage = 3.7
capacity = 2500
energy = voltage * capacity / 1000
print(f"The energy stored in the battery is {energy} Wh.")
# Out:
# The energy stored in the battery is 9.25 Wh.

# %%
voltage = float(input("Enter the voltage of the battery: "))
capacity = float(input("Enter the capacity of the battery in mAh: "))
energy = voltage * capacity / 1000
print(f"The energy stored in the battery is {energy: .3f} Wh.")
# Out:
# The energy stored in the battery is  3.077 Wh.

# %%
cell_voltages = [3.7, 3.6, 3.8, 3.9, 3.5]
total_voltage = sum(cell_voltages)
print(f"The total voltage of the cells is {total_voltage:.2f} V.")
average_voltage = sum(cell_voltages) / len(cell_voltages)
print(f"The average voltage of the cells is {average_voltage:.2f} V.")
# Out:
# The total voltage of the cells is 18.50 V.
# The average voltage of the cells is 3.70 V.

# %%
while True:
    try:
        cell_number = int(input("Enter the number of cells: "))
        if cell_number <= 0:
            print("Error: please enter an integer greater than 0.")
            continue
        break
    except ValueError:
        print("Error: please enter a valid integer greater than 0.")

voltages = []
for i in range(cell_number):
    while True:
        try:
            voltage_input = input(f"Enter the voltage of cell {i + 1}: ")
            voltage = float(voltage_input)
            break
        except ValueError:
            print("Error: please enter a valid number for voltage.")
    voltages.append(voltage)

total_voltage = sum(voltages)
print(f"The total voltage of the cells is {total_voltage:.2f} V.")
average_voltage = sum(voltages) / len(voltages)
print(f"The average voltage of the cells is {average_voltage:.2f} V.")
# Out:
# The total voltage of the cells is 57.90 V.
# The average voltage of the cells is 28.95 V.

# %%
cell_voltages = [3.7, 3.6, 3.8, 3.9, 3.5]
lowest_voltage = min(cell_voltages)
highest_voltage = max(cell_voltages)
print(f"The lowest voltage among the cells is {lowest_voltage:.2f} V.")
print(f"The highest voltage among the cells is {highest_voltage:.2f} V.")
lowest_cell_index = cell_voltages.index(lowest_voltage) + 1
highest_cell_index = cell_voltages.index(highest_voltage) + 1
print(f"Cell {lowest_cell_index} has the lowest voltage.")
print(f"Cell {highest_cell_index} has the highest voltage.")
# Out:
# The lowest voltage among the cells is 3.50 V.
# The highest voltage among the cells is 3.90 V.
# Cell 5 has the lowest voltage.
# Cell 4 has the highest voltage.

# %%
current_voltage = 3.0
while current_voltage < 4.2:
    print(f"Charging.... Current voltage: {current_voltage:.2f} V")
    current_voltage += 0.1
print("Battery fully charged!")
# Out:
# Charging.... Current voltage: 3.00 V
# Charging.... Current voltage: 3.10 V
# Charging.... Current voltage: 3.20 V
# Charging.... Current voltage: 3.30 V
# Charging.... Current voltage: 3.40 V
# Charging.... Current voltage: 3.50 V
# Charging.... Current voltage: 3.60 V
# Charging.... Current voltage: 3.70 V
# Charging.... Current voltage: 3.80 V
# Charging.... Current voltage: 3.90 V
# Charging.... Current voltage: 4.00 V
# Charging.... Current voltage: 4.10 V
# Battery fully charged!

# %%
import numpy as np

# %%
voltage_list = np.array([3.7, 3.6, 3.8, 3.9, 3.5, 3.4])
print("Engineer's voltage list:", voltage_list)
v_charge = voltage_list + 0.1
print("Voltage list after charging:", v_charge)
mean_voltage = np.mean(voltage_list)
print(f"Mean voltage: {mean_voltage:.2f} V")
std_voltage = np.std(voltage_list)
print(f"Standard deviation of voltage: {std_voltage:.2f} V")
max_voltage = np.max(voltage_list)
print(f"Maximum voltage: {max_voltage:.2f} V")
min_voltage = np.min(voltage_list)
print(f"Minimum voltage: {min_voltage:.2f} V")
bad_cells = voltage_list < 3.6
print("Bad cells (voltage < 3.6 V):", bad_cells)
print("Indices of bad cells:", np.where(bad_cells)[0] + 1)
print("Critical cells (voltage < 3.5 V):", voltage_list[voltage_list < 3.6])
if np.min(voltage_list) < 3.5:
    print("Warning: Critical cell detected! Emergency Shutdown initiated.")
else:
    print("All cells are within safe voltage range.")
# Out:
# Engineer's voltage list: [3.7 3.6 3.8 3.9 3.5 3.4]
# Voltage list after charging: [3.8 3.7 3.9 4.  3.6 3.5]
# Mean voltage: 3.65 V
# Standard deviation of voltage: 0.17 V
# Maximum voltage: 3.90 V
# Minimum voltage: 3.40 V
# Bad cells (voltage < 3.6 V): [False False False False  True  True]
# Indices of bad cells: [5 6]
# Critical cells (voltage < 3.5 V): [3.5 3.4]
# ...
